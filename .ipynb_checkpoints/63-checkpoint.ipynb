# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('63.csv')
df
# Out:
#                           Timestamp Roll_No            Student_Name  \
# 0    2023/10/03 6:03:37 PM GMT+5:30    TF18           Swayam Shinde
# 1    2023/10/03 6:31:21 PM GMT+5:30   TF004  Mrunalini Anil Shinde
# 2    2023/10/03 8:39:11 PM GMT+5:30   TE027     Mande Sarvesh Anil
# 3    2023/10/03 8:40:22 PM GMT+5:30   TE025   Gore Harshad Prakash
# 4    2023/10/03 8:41:20 PM GMT+5:30   TE001          Aakash Pasare
# ..                              ...     ...                     ...
# 58   2023/10/05 3:31:47 PM GMT+5:30  Tyf065          Jayesh Nerkar
# 59   2023/10/05 3:32:25 PM GMT+5:30      16              Soham more
# 60   2023/10/05 9:21:07 PM GMT+5:30   TE029    Swati Shriram Uchale
# 61  2023/10/05 10:12:47 PM GMT+5:30   TF032      Kunal Santosh Bhor
# 62   2023/10/07 6:55:45 PM GMT+5:30    TD50     Snehal sopan satkar
#
#           Class Division  SGPA_1  SGPA_2  SGPA_3  SGPA_4  SGPA_5
# 0   T.Y.BSC(CS)        F    8.70    6.50    7.36    8.32    8.00
# ...

# %%
df.drop(['Timestamp', 'Roll_No', 'Student_Name', 'Class', 'Division'], axis = 1, inplace = True)
df
# Out:
#     SGPA_1  SGPA_2  SGPA_3  SGPA_4  SGPA_5
# 0     8.70    6.50    7.36    8.32    8.00
# 1     8.80    7.93    8.27    8.82    9.00
# 2     7.32    8.18    8.36    8.64    8.50
# 3     9.09    9.68    9.55    9.91    9.50
# 4     9.02    8.66    8.44    8.27    8.55
# ..     ...     ...     ...     ...     ...
# 58    8.90    7.00    7.80    6.90    8.90
# 59    8.09    7.49    8.27    8.91    8.27
# 60    7.14    6.93    8.09    7.45    7.00
# 61    8.43    7.16    7.73    8.45    8.00
# 62    8.57    7.93    7.45    8.73    9.00
#
# [63 rows x 5 columns]

# %%
df['SGPA_2'] - df['SGPA_1']
# Out:
# 0    -2.20
# 1    -0.87
# 2     0.86
# 3     0.59
# 4    -0.36
#       ...
# 58   -1.90
# 59   -0.60
# 60   -0.21
# 61   -1.27
# 62   -0.64
# Length: 63, dtype: float64

# %%
df['SGPA_3'] - df['SGPA_2']
# Out:
# 0     0.86
# 1     0.34
# 2     0.18
# 3    -0.13
# 4    -0.22
#       ...
# 58    0.80
# 59    0.78
# 60    1.16
# 61    0.57
# 62   -0.48
# Length: 63, dtype: float64

# %%
df['SGPA_4'] - df['SGPA_3']
# Out:
# 0     0.96
# 1     0.55
# 2     0.28
# 3     0.36
# 4    -0.17
#       ...
# 58   -0.90
# 59    0.64
# 60   -0.64
# 61    0.72
# 62    1.28
# Length: 63, dtype: float64

# %%
df['SGPA5'] = df['SGPA_4'] + (df['SGPA_4'] - df['SGPA_3']) + (df['SGPA_3'] - df['SGPA_2']) + (df['SGPA_2'] - df['SGPA_1'])
df
# Out:
#     SGPA_1  SGPA_2  SGPA_3  SGPA_4  SGPA_5  SGPA5
# 0     8.70    6.50    7.36    8.32    8.00   7.94
# 1     8.80    7.93    8.27    8.82    9.00   8.84
# 2     7.32    8.18    8.36    8.64    8.50   9.96
# 3     9.09    9.68    9.55    9.91    9.50  10.73
# 4     9.02    8.66    8.44    8.27    8.55   7.52
# ..     ...     ...     ...     ...     ...    ...
# 58    8.90    7.00    7.80    6.90    8.90   4.90
# 59    8.09    7.49    8.27    8.91    8.27   9.73
# 60    7.14    6.93    8.09    7.45    7.00   7.76
# 61    8.43    7.16    7.73    8.45    8.00   8.47
# 62    8.57    7.93    7.45    8.73    9.00   8.89
#
# [63 rows x 6 columns]

# %%
df[df['SGPA5'] < df['SGPA_4']].shape
# Out:
# (30, 6)

# %%
# for i in df['SGPA5']:
#     if i > 10:
#         df['SGPA5'] = 10
df
# Out:
#     SGPA_1  SGPA_2  SGPA_3  SGPA_4  SGPA_5  SGPA5
# 0     8.70    6.50    7.36    8.32    8.00   7.94
# 1     8.80    7.93    8.27    8.82    9.00   8.84
# 2     7.32    8.18    8.36    8.64    8.50   9.96
# 3     9.09    9.68    9.55    9.91    9.50  10.73
# 4     9.02    8.66    8.44    8.27    8.55   7.52
# ..     ...     ...     ...     ...     ...    ...
# 58    8.90    7.00    7.80    6.90    8.90   4.90
# 59    8.09    7.49    8.27    8.91    8.27   9.73
# 60    7.14    6.93    8.09    7.45    7.00   7.76
# 61    8.43    7.16    7.73    8.45    8.00   8.47
# 62    8.57    7.93    7.45    8.73    9.00   8.89
#
# [63 rows x 6 columns]

# %%
# for i in df[df['SGPA5'] < df['SGPA_4']]['SGPA5'] :

# %%
# if df['SGPA5'] < df['SGPA_4'] :
    
    # df['SGPA5'] = df['SGPA_4'] +

# %%
df.hist(figsize = (20,10), color = 'darkorange', edgecolor = 'black');

# %%
sns.pairplot(df)
# Out:
# C:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dfcorr = df.corr()
dfcorr
# Out:
#           SGPA_1    SGPA_2    SGPA_3    SGPA_4    SGPA_5     SGPA5
# SGPA_1  1.000000  0.507901  0.378706  0.447167  0.404232  0.009140
# SGPA_2  0.507901  1.000000  0.647936  0.666855  0.411573  0.496252
# SGPA_3  0.378706  0.647936  1.000000  0.651660  0.464544  0.542670
# SGPA_4  0.447167  0.666855  0.651660  1.000000  0.544952  0.898500
# SGPA_5  0.404232  0.411573  0.464544  0.544952  1.000000  0.410846
# SGPA5   0.009140  0.496252  0.542670  0.898500  0.410846  1.000000

# %%
sns.heatmap(dfcorr, annot = True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SGPA_1  63 non-null     float64
#  1   SGPA_2  63 non-null     float64
#  2   SGPA_3  63 non-null     float64
#  3   SGPA_4  63 non-null     float64
#  4   SGPA_5  63 non-null     float64
#  5   SGPA5   63 non-null     float64
# dtypes: float64(6)
# memory usage: 3.1 KB

# %%
X = df[['SGPA_1', 'SGPA_2', 'SGPA_3', 'SGPA_4']]
X
# Out:
#     SGPA_1  SGPA_2  SGPA_3  SGPA_4
# 0     8.70    6.50    7.36    8.32
# 1     8.80    7.93    8.27    8.82
# 2     7.32    8.18    8.36    8.64
# 3     9.09    9.68    9.55    9.91
# 4     9.02    8.66    8.44    8.27
# ..     ...     ...     ...     ...
# 58    8.90    7.00    7.80    6.90
# 59    8.09    7.49    8.27    8.91
# 60    7.14    6.93    8.09    7.45
# 61    8.43    7.16    7.73    8.45
# 62    8.57    7.93    7.45    8.73
#
# [63 rows x 4 columns]

# %%
y = df['SGPA5']
y
# Out:
# 0      7.94
# 1      8.84
# 2      9.96
# 3     10.73
# 4      7.52
#       ...
# 58     4.90
# 59     9.73
# 60     7.76
# 61     8.47
# 62     8.89
# Name: SGPA5, Length: 63, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50, 4), (13, 4), (50,), (13,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 1.0

# %%
lr.score(X_train, y_train)
# Out:
# 1.0
